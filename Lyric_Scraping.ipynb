# %%
pip install lyricsgenius
# Out:
# Collecting lyricsgenius
#   Downloading lyricsgenius-3.0.1-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 kB 4.4 MB/s eta 0:00:00
# Collecting beautifulsoup4>=4.6.0 (from lyricsgenius)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting requests>=2.20.0 (from lyricsgenius)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.6.0->lyricsgenius)
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.20.0->lyricsgenius)
#   Downloading charset_normalizer-3.3.2-cp38-cp38-macosx_10_9_x86_64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests>=2.20.0->lyricsgenius)
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.20.0->lyricsgenius)
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.20.0->lyricsgenius)
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 9.9 MB/s eta 0:00:00
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 8.9 MB/s eta 0:00:00
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 4.2 MB/s eta 0:00:00a 0:00:01
# Downloading charset_normalizer-3.3.2-cp38-cp38-macosx_10_9_x86_64.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 6.7 MB/s eta 0:00:00
# Downloading idna-3.6-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 7.1 MB/s eta 0:00:00
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 11.6 MB/s eta 0:00:00
# Installing collected packages: urllib3, soupsieve, idna, charset-normalizer, certifi, requests, beautifulsoup4, lyricsgenius
# Successfully installed beautifulsoup4-4.12.3 certifi-2024.2.2 charset-normalizer-3.3.2 idna-3.6 lyricsgenius-3.0.1 requests-2.31.0 soupsieve-2.5 urllib3-2.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from lyricsgenius import Genius
# Out:
#                    track            artist
# 0  Jealous Kind Of Fella     Garland Green
# 1          Initials B.B.  Serge Gainsbourg
# 2           Melody Twist       Lord Melody
# 3          Mi Bomba Sonó        Celia Cruz
# 4            Uravu Solla       P. Susheela

# %%
df = pd.read_csv("data/archive/for_scraping.csv")
df.head()
# Out:
#                    track            artist  \
# 0  Jealous Kind Of Fella     Garland Green
# 1          Initials B.B.  Serge Gainsbourg
# 2           Melody Twist       Lord Melody
# 3          Mi Bomba Sonó        Celia Cruz
# 4            Uravu Solla       P. Susheela
#
#                                               lyrics
# 0  3 ContributorsJealous Kind of Fella Lyrics[Int...
# 1  14 ContributorsInitials B.B. Lyrics[Paroles de...
# 2  1 ContributorJuice (haeY haeY) LyricsHook (Kro...
# 3  2 ContributorsMi Bomba Sonó LyricsAcó, mi bomb...
# 4                                                  0

# %%
# df["lyrics"] = None
# df.to_csv("data/archive/for_scraping.csv",index=False)

# %%
# Example

genius = Genius("7l4X7aWeE1SZ6fEJIFyFOI2v515nbib89wRj0WRaPV12cfWJMqzcw3zYDaC8_21V")
artist = genius.search_artist("Andy Shauf", max_songs=3, sort="title")
print(artist.songs)
# Out:
# Searching for songs by Andy Shauf...
#
# Song 1: "Alexander All Alone"
# Song 2: "All Of My Love"
# Song 3: "All the Same"
#
# Reached user-specified song limit (3).
# Done. Found 3 songs.
# [Song(id, artist, ...), Song(id, artist, ...), Song(id, artist, ...)]

# %%
genius.verbose = True

# %%
df = pd.read_csv("data/archive/for_scraping.csv")
for index, row in df.iterrows():
    if not pd.isna(row["lyrics"]):
        continue
    track = row["track"]
    artist = row["artist"]
    print((index, track, artist))
    searching = True
    while searching:
        try:
            song = genius.search_song(track, artist)
            searching = False
        except Exception:
            pass
    if not song:
        df.at[index, "lyrics"] = 0
    else:
        df.at[index, "lyrics"] = song.lyrics
    df.to_csv("data/archive/for_scraping.csv",index=False)
# Out:
# (258, "California Dreamin'", 'The Mamas & The Papas')
# Searching for "California Dreamin'" by The Mamas & The Papas...
# Done.
# (259, 'Point Of No Return', 'Adam Wade')
# Searching for "Point Of No Return" by Adam Wade...
# Done.
# (260, 'Remember When', 'Wayne Newton')
# Searching for "Remember When" by Wayne Newton...
# Done.
# (261, 'That Old Black Magic', 'Bobby Rydell')
# Searching for "That Old Black Magic" by Bobby Rydell...
# Done.
# (262, 'Sunday For Tea', 'Peter And Gordon')
# Searching for "Sunday For Tea" by Peter And Gordon...
# Done.
# (263, 'Puñalada Trapera', 'Amalia Mendoza')
# Searching for "Puñalada Trapera" by Amalia Mendoza...
# Done.
# (264, 'Eternally', 'The Chantels')
# Searching for "Eternally" by The Chantels...
# Done.
# (265, 'Young And In Love', 'Chris Crosby')
# Searching for "Young And In Love" by Chris Crosby...
# Done.
# (266, 'Acompáñame', 'Enrique Guzman')
# Searching for "Acompáñame" by Enrique Guzman...
# Done.
# (267, 'Bataille de Zaccar', 'André Hossein')
# Searching for "Bataille de Zaccar" by André Hossein...
# Done.
# (268, '3rd Man Theme', 'Herb Alpert & The Tijuana Brass')
# Searching for "3rd Man Theme" by Herb Alpert & The Tijuana Brass...
# Specified song does not contain lyrics. Rejecting.
# (269, 'Saturday Night At The Movies', 'The Drifters')
# Searching for "Saturday Night At The Movies" by The Drifters...
# Done.
# (270, 'Music for Percussion (Nos. 8 - 13)', 'Laurie Johnson')
# Searching for "Music for Percussion (Nos. 8 - 13)" by Laurie Johnson...
# No results found for: 'Music for Percussion (Nos. 8 - 13) Laurie Johnson'
# (271, 'Dorme Dorme Menininha', 'Sérgio Ricardo')
# Searching for "Dorme Dorme Menininha" by Sérgio Ricardo...
# No results found for: 'Dorme Dorme Menininha Sérgio Ricardo'
# (272, "Bill Bailey, Won't You Please Come Home", 'Ella Fitzgerald')
# Searching for "Bill Bailey, Won't You Please Come Home" by Ella Fitzgerald...
# Done.
# (273, 'Total Blues', 'Francy Boland')
# Searching for "Total Blues" by Francy Boland...
# Done.
# (274, 'All I Have To Do Is Take A Bite Of Your Apple?', 'Jerry Goldsmith')
# Searching for "All I Have To Do Is Take A Bite Of Your Apple?" by Jerry Goldsmith...
# Specified song does not contain lyrics. Rejecting.
# (275, 'The Drum Thing', 'John Coltrane Quartet')
# Searching for "The Drum Thing" by John Coltrane Quartet...
# Specified song does not contain lyrics. Rejecting.
# (276, 'Madama Butterfly, Act II: Povera Butterfly (Suzuki, Sharpless, Butterfly)', 'Giacomo Puccini')
# Searching for "Madama Butterfly, Act II: Povera Butterfly (Suzuki, Sharpless, Butterfly)" by Giacomo Puccini...
# No results found for: 'Madama Butterfly, Act II: Povera Butterfly (Suzuki, Sharpless, Butterfly) Giacomo Puccini'
# (277, 'Come Back Silly Girl', 'The Lettermen')
# Searching for "Come Back Silly Girl" by The Lettermen...
# Done.
# (278, 'Bring It On Home To Me', 'Eddie Floyd')
# Searching for "Bring It On Home To Me" by Eddie Floyd...
# Done.
# (279, 'Foggy Mountain Breakdown', 'Flatt & Scruggs')
# Searching for "Foggy Mountain Breakdown" by Flatt & Scruggs...
# Specified song does not contain lyrics. Rejecting.
# (280, "Rigoletto [Acts II & III]: V'ho ingannato....Lassù in cielo (Gilda, Rigoletto)", 'Giuseppe Verdi')
# Searching for "Rigoletto [Acts II & III]: V'ho ingannato....Lassù in cielo (Gilda, Rigoletto)" by Giuseppe Verdi...
# No results found for: 'Rigoletto [Acts II & III]: V'ho ingannato....Lassù in cielo (Gilda, Rigoletto) Giuseppe Verdi'
# (281, 'Orupoo Orupoo', 'P. Susheela')
# Searching for "Orupoo Orupoo" by P. Susheela...
# No results found for: 'Orupoo Orupoo P. Susheela'
# (282, "Tonight's The Night", 'Solomon Burke')
# Searching for "Tonight's The Night" by Solomon Burke...
# Done.
# (283, 'Carolina', 'Chico Buarque')
# Searching for "Carolina" by Chico Buarque...
# Done.
# (284, "La fille du régiment / Act 1: Sacré nom d'une pipe!", 'Gaetano Donizetti')
# Searching for "La fille du régiment / Act 1: Sacré nom d'une pipe!" by Gaetano Donizetti...
# No results found for: 'La fille du régiment / Act 1: Sacré nom d'une pipe! Gaetano Donizetti'
# (285, '31 Flavors', 'The Shirelles')
# Searching for "31 Flavors" by The Shirelles...
# Done.
# (286, 'Brooklyn Roads', 'Neil Diamond')
# Searching for "Brooklyn Roads" by Neil Diamond...
# Done.
# (287, 'Daydream Believer', 'The Monkees')
# Searching for "Daydream Believer" by The Monkees...
# Done.
# (288, 'Mame', 'Herb Alpert & The Tijuana Brass')
# Searching for "Mame" by Herb Alpert & The Tijuana Brass...
# Done.
# (289, "Maily's Abduction", 'Jerry Goldsmith')
# Searching for "Maily's Abduction" by Jerry Goldsmith...
# No results found for: 'Maily's Abduction Jerry Goldsmith'
# (290, 'Come On And See Me', 'Tammi Terrell')
# Searching for "Come On And See Me" by Tammi Terrell...
# Done.
# (291, 'Soul Serenade', 'Willie Mitchell')
# Searching for "Soul Serenade" by Willie Mitchell...
# Done.
# (292, "Doggin' Around", 'Jackie Wilson')
# Searching for "Doggin' Around" by Jackie Wilson...
# Done.
# (293, 'I Got You Babe', 'Sonny & Cher')
# Searching for "I Got You Babe" by Sonny & Cher...
# Done.
# (294, "My Lover's Prayer", 'Otis Redding')
# Searching for "My Lover's Prayer" by Otis Redding...
# Done.
# (295, 'Joy to the World - Remastered 1997', 'George Frideric Handel')
# Searching for "Joy to the World - Remastered 1997" by George Frideric Handel...
# Done.
# (296, 'Monster Jerk', 'Don Hinson & The Rigamorticians')
# Searching for "Monster Jerk" by Don Hinson & The Rigamorticians...
# No results found for: 'Monster Jerk Don Hinson & The Rigamorticians'
# (297, 'La Luna Siempre Es Muy Linda', 'Victor Jara')
# Searching for "La Luna Siempre Es Muy Linda" by Victor Jara...
# Done.
# (298, "You Don't Own Me", 'Lesley Gore')
# Searching for "You Don't Own Me" by Lesley Gore...
# Done.
# (299, 'Pop Pop Pop - Pie', 'The Sherrys')
# Searching for "Pop Pop Pop - Pie" by The Sherrys...
# Done.
# (300, 'Over Under Sideways Down', 'The Yardbirds')
# Searching for "Over Under Sideways Down" by The Yardbirds...
# Done.
# (301, 'Jane, Jane, Jane', 'The Kingston Trio')
# Searching for "Jane, Jane, Jane" by The Kingston Trio...
# Done.
# (302, 'Little Red Rented Rowboat', 'Joe Dowell')
# Searching for "Little Red Rented Rowboat" by Joe Dowell...
# Done.
# (303, 'Gravy (With Some Cyanide)', 'John Zacherle')
# Searching for "Gravy (With Some Cyanide)" by John Zacherle...
# No results found for: 'Gravy (With Some Cyanide) John Zacherle'
# (304, 'Ennai Padavaithavan Oruvan', 'P. Susheela')
# Searching for "Ennai Padavaithavan Oruvan" by P. Susheela...
# No results found for: 'Ennai Padavaithavan Oruvan P. Susheela'
# (305, 'At The Scene', 'The Dave Clark Five')
# Searching for "At The Scene" by The Dave Clark Five...
# Done.
# (306, "El Testament d'Amelia", 'Traditional')
# Searching for "El Testament d'Amelia" by Traditional...
# No results found for: 'El Testament d'Amelia Traditional'
# (307, "Men Are Gettin' Scarce", 'Joe Tex')
# Searching for "Men Are Gettin' Scarce" by Joe Tex...
# Done.
# (308, 'No Good To Cry', 'The Wildweeds')
# Searching for "No Good To Cry" by The Wildweeds...
# Done.
# (309, 'Tone the Bell Easy', 'Harry Belafonte')
# Searching for "Tone the Bell Easy" by Harry Belafonte...
# Done.
# (310, 'Hold Me Tight', 'Johnny Nash')
# Searching for "Hold Me Tight" by Johnny Nash...
# Done.
# (311, 'Der Waffenschmied: Akt I - "Bringt eilig Hut und Mantel mir!"', 'Staatskapelle Berlin')
# Searching for "Der Waffenschmied: Akt I - "Bringt eilig Hut und Mantel mir!"" by Staatskapelle Berlin...
# No results found for: 'Der Waffenschmied: Akt I - "Bringt eilig Hut und Mantel mir!" Staatskapelle Berlin'
# (312, 'Guantanamera', 'Celia Cruz')
# Searching for "Guantanamera" by Celia Cruz...
# Done.
# (313, 'Bataille', 'André Hossein')
# Searching for "Bataille" by André Hossein...
# Done.
# (314, 'Penny Lane', 'The Beatles')
# Searching for "Penny Lane" by The Beatles...
# Done.
# (315, 'Try A Little Kindness', 'Glen Campbell')
# Searching for "Try A Little Kindness" by Glen Campbell...
# Done.
# (316, 'Ling-Ting-Tong', 'Buddy Knox')
# Searching for "Ling-Ting-Tong" by Buddy Knox...
# No results found for: 'Ling-Ting-Tong Buddy Knox'
# (317, 'For As Long As We Need You', 'Maurice Jarre')
# Searching for "For As Long As We Need You" by Maurice Jarre...
# Done.
# (318, 'How Could I Be Such A Fool', 'Frank Zappa')
# Searching for "How Could I Be Such A Fool" by Frank Zappa...
# Done.
# (319, 'O World / Morning Worship / Prophet', 'Mark Van Doren')
# Searching for "O World / Morning Worship / Prophet" by Mark Van Doren...
# Done.
# (320, 'Rigoletto [Acts II & III]: Un dì, se ben rammentomi (Duke, Gilda, Maddalena, Rigoletto)', 'Giuseppe Verdi')
# Searching for "Rigoletto [Acts II & III]: Un dì, se ben rammentomi (Duke, Gilda, Maddalena, Rigoletto)" by Giuseppe Verdi...
# No results found for: 'Rigoletto [Acts II & III]: Un dì, se ben rammentomi (Duke, Gilda, Maddalena, Rigoletto) Giuseppe Verdi'
# (321, 'Lara\'s Theme from "Dr. Zhivago"', 'Roger Williams')
# Searching for "Lara's Theme from "Dr. Zhivago"" by Roger Williams...
# No results found for: 'Lara's Theme from "Dr. Zhivago" Roger Williams'
# (322, 'Tosca (Sung in German): Act I: Ha! Das gelang mir! (Angelotti)', 'Giacomo Puccini')
# Searching for "Tosca (Sung in German): Act I: Ha! Das gelang mir! (Angelotti)" by Giacomo Puccini...
# No results found for: 'Tosca (Sung in German): Act I: Ha! Das gelang mir! (Angelotti) Giacomo Puccini'
# (323, "Sprit's Song", 'Louise Bogan')
# Searching for "Sprit's Song" by Louise Bogan...
# Done.
# (324, 'Testify (I Wonna)', 'Johnnie Taylor')
# Searching for "Testify (I Wonna)" by Johnnie Taylor...
# Done.
# (325, "There's No Living Without Your Loving", 'Peter And Gordon')
# Searching for "There's No Living Without Your Loving" by Peter And Gordon...
# Done.
# (326, 'Blue Moon', 'The Ventures')
# Searching for "Blue Moon" by The Ventures...
# Specified song does not contain lyrics. Rejecting.
# (327, "You've Made Me So Very Happy", 'Brenda Holloway')
# Searching for "You've Made Me So Very Happy" by Brenda Holloway...
# Done.
# (328, "She's A Lady", 'John Sebastian')
# Searching for "She's A Lady" by John Sebastian...
# Done.
# (329, 'If I Ruled The World', 'Tony Bennett')
# Searching for "If I Ruled The World" by Tony Bennett...
# Done.
# (330, "I'm Henry VIII, I Am", "Herman's Hermits")
# Searching for "I'm Henry VIII, I Am" by Herman's Hermits...
# Done.
# (331, 'Little Queenie', "Bill Black's Combo")
# Searching for "Little Queenie" by Bill Black's Combo...
# Specified song does not contain lyrics. Rejecting.
# (332, 'Sleepy Joe', "Herman's Hermits")
# Searching for "Sleepy Joe" by Herman's Hermits...
# Done.
# (333, 'Carmen: Act II - "Sag, wen erwartest du?"', 'Leipzig Radio Symphony Orchestra')
# Searching for "Carmen: Act II - "Sag, wen erwartest du?"" by Leipzig Radio Symphony Orchestra...
# No results found for: 'Carmen: Act II - "Sag, wen erwartest du?" Leipzig Radio Symphony Orchestra'
# (334, 'Mis Blues', 'Krokodil')
# Searching for "Mis Blues" by Krokodil...
# Done.
# (335, 'Shake A Tail Feather', 'James & Bobby Purify')
# Searching for "Shake A Tail Feather" by James & Bobby Purify...
# Done.
# (336, "Mickey's Son And Daughter - 2007 Remastered Version", 'The Bonzo Dog Band')
# Searching for "Mickey's Son And Daughter - 2007 Remastered Version" by The Bonzo Dog Band...
# No results found for: 'Mickey's Son And Daughter - 2007 Remastered Version The Bonzo Dog Band'
# (337, 'All Green', 'Xhol Caravan')
# Searching for "All Green" by Xhol Caravan...
# No results found for: 'All Green Xhol Caravan'
# (338, 'Gee', 'The Pixies Three')
# Searching for "Gee" by The Pixies Three...
# Done.
# (339, "Help Yourself (To All Of My Lovin')", 'James & Bobby Purify')
# Searching for "Help Yourself (To All Of My Lovin')" by James & Bobby Purify...
# No results found for: 'Help Yourself (To All Of My Lovin') James & Bobby Purify'
# (340, 'Viva Mi Desgracia', 'Vicente Fernández')
# Searching for "Viva Mi Desgracia" by Vicente Fernández...
# Done.
# (341, 'Saladino 7', 'Angelo Francesco Lavagnino')
# Searching for "Saladino 7" by Angelo Francesco Lavagnino...
# No results found for: 'Saladino 7 Angelo Francesco Lavagnino'
# (342, 'Ahir (Diguem No). Bis - En Directe', 'Raimon')
# Searching for "Ahir (Diguem No). Bis - En Directe" by Raimon...
# Done.
# (343, "L'Elisir d'amore, 'Elixir of Love' (1988 Digital Remaster), Act I: Signor sargente", 'Gaetano Donizetti')
# Searching for "L'Elisir d'amore, 'Elixir of Love' (1988 Digital Remaster), Act I: Signor sargente" by Gaetano Donizetti...
# No results found for: 'L'Elisir d'amore, 'Elixir of Love' (1988 Digital Remaster), Act I: Signor sargente Gaetano Donizetti'
# (344, 'Phonograph', 'Jerry Goldsmith')
# Searching for "Phonograph" by Jerry Goldsmith...
# Done.
# (345, 'She Comes Running - 2007 Remaster', 'Lee Hazlewood')
# Searching for "She Comes Running - 2007 Remaster" by Lee Hazlewood...
# Done.
# (346, 'Dizzy', 'Tommy Roe')
# Searching for "Dizzy" by Tommy Roe...
# Done.
# (347, 'When I Fall In Love', 'Etta Jones')
# Searching for "When I Fall In Love" by Etta Jones...
# Done.
# (348, "Autumn's Child - Mono", 'Captain Beefheart & His Magic Band')
# Searching for "Autumn's Child - Mono" by Captain Beefheart & His Magic Band...
# No results found for: 'Autumn's Child - Mono Captain Beefheart & His Magic Band'
# (349, "Climb Ev'ry Mountain", 'Tony Bennett')
# Searching for "Climb Ev'ry Mountain" by Tony Bennett...
# Done.
# (350, 'First Warning #2', 'Jerry Goldsmith')
# Searching for "First Warning #2" by Jerry Goldsmith...
# No results found for: 'First Warning #2 Jerry Goldsmith'
# (351, "Cleo's Mood", 'Jr. Walker & The All Stars')
# Searching for "Cleo's Mood" by Jr. Walker & The All Stars...
# Specified song does not contain lyrics. Rejecting.
# (352, 'Cantando', 'Vicente Fernández')
# Searching for "Cantando" by Vicente Fernández...
# Done.
# (353, 'Loddy Lo', 'Chubby Checker')
# Searching for "Loddy Lo" by Chubby Checker...
# Done.
# (354, 'Well, I Told You', 'The Chantels')
# Searching for "Well, I Told You" by The Chantels...
# Done.
# (355, 'Hey! Baby', 'Bruce Channel')
# Searching for "Hey! Baby" by Bruce Channel...
# Done.
# (356, 'El Paso', 'Marty Robbins')
# Searching for "El Paso" by Marty Robbins...
# Searching for "El Paso" by Marty Robbins...
# Done.
# (357, 'Delia', 'Harry Belafonte')
# Searching for "Delia" by Harry Belafonte...
# Done.
# (358, 'Billie Baby', 'Lloyd Price')
# Searching for "Billie Baby" by Lloyd Price...
# Done.
# (359, "He Don't Really Love You", 'The Delfonics')
# Searching for "He Don't Really Love You" by The Delfonics...
# Done.
# (360, 'You Send Me', 'Aretha Franklin')
# Searching for "You Send Me" by Aretha Franklin...
# Done.
# (361, "You're Looking Good", 'Dee Clark')
# Searching for "You're Looking Good" by Dee Clark...
# Done.
# (362, 'John the Revelator', 'Harry Belafonte')
# Searching for "John the Revelator" by Harry Belafonte...
# Done.
# (363, 'Heart Love', 'Albert Ayler')
# Searching for "Heart Love" by Albert Ayler...
# Done.
# (364, 'I Love You More And More Every Day', 'Al Martino')
# Searching for "I Love You More And More Every Day" by Al Martino...
# Done.
# (365, 'Ninna Nanna per Adulteri - Version 2', 'Ennio Morricone')
# Searching for "Ninna Nanna per Adulteri - Version 2" by Ennio Morricone...
# No results found for: 'Ninna Nanna per Adulteri - Version 2 Ennio Morricone'
# (366, 'Desperado - Intro lenta tensiva', 'Gianni Ferrio')
# Searching for "Desperado - Intro lenta tensiva" by Gianni Ferrio...
# Done.
# (367, 'Space - Live At The Jazz Workshop, Boston/1967', 'Gábor Szabó')
# Searching for "Space - Live At The Jazz Workshop, Boston/1967" by Gábor Szabó...
# No results found for: 'Space - Live At The Jazz Workshop, Boston/1967 Gábor Szabó'
# (368, 'I Love My Baby', 'Archie Bell & The Drells')
# Searching for "I Love My Baby" by Archie Bell & The Drells...
# Done.
# (369, 'Water', 'Silver Apples')
# Searching for "Water" by Silver Apples...
# Done.
# (370, 'Close Together', 'Jimmy Reed')
# Searching for "Close Together" by Jimmy Reed...
# Done.
# (371, 'Watch Her Ride', 'Jefferson Airplane')
# Searching for "Watch Her Ride" by Jefferson Airplane...
# Done.
# (372, 'Oscillations', 'Silver Apples')
# Searching for "Oscillations" by Silver Apples...
# Done.
# (373, 'Billy the Kid Suite: III. Mexican Dance and Finale', 'Aaron Copland')
# Searching for "Billy the Kid Suite: III. Mexican Dance and Finale" by Aaron Copland...
# No results found for: 'Billy the Kid Suite: III. Mexican Dance and Finale Aaron Copland'
# (374, 'The Greatest Love', 'Dorsey Burnette')
# Searching for "The Greatest Love" by Dorsey Burnette...
# Done.
# (375, 'Challenge', 'The Hippy Boys')
# Searching for "Challenge" by The Hippy Boys...
# Done.
# (376, 'Ballad Of Two Brothers', 'Autry Inman')
# Searching for "Ballad Of Two Brothers" by Autry Inman...
# Done.
# (377, 'Eso Beso (That Kiss!)', 'Paul Anka')
# Searching for "Eso Beso (That Kiss!)" by Paul Anka...
# Done.
# (378, 'The Death Of Aki', 'John Barry')
# Searching for "The Death Of Aki" by John Barry...
# Done.
# (379, 'Tears', 'Bobby Vinton')
# Searching for "Tears" by Bobby Vinton...
# Done.
# (380, "Gee Baby (I'm Sorry)", 'The Three Degrees')
# Searching for "Gee Baby (I'm Sorry)" by The Three Degrees...
# Done.
# (381, 'The Work Song', 'Herb Alpert & The Tijuana Brass')
# Searching for "The Work Song" by Herb Alpert & The Tijuana Brass...
# Specified song does not contain lyrics. Rejecting.
# (382, '(Theme From) Valley Of The Dolls', 'Dionne Warwick')
# Searching for "(Theme From) Valley Of The Dolls" by Dionne Warwick...
# Done.
# (383, 'Dos Gardenias', 'La Sonora Matancera')
# Searching for "Dos Gardenias" by La Sonora Matancera...
# No results found for: 'Dos Gardenias La Sonora Matancera'
# (384, 'Yesterday', 'La Lupe')
# Searching for "Yesterday" by La Lupe...
# Done.
# (385, 'So What', "Bill Black's Combo")
# Searching for "So What" by Bill Black's Combo...
# Done.
# (386, 'La Traviata - Opera in three acts (1992 Digital Remaster), Act II: Alfredo! Voi!', 'Giuseppe Verdi')
# Searching for "La Traviata - Opera in three acts (1992 Digital Remaster), Act II: Alfredo! Voi!" by Giuseppe Verdi...
# No results found for: 'La Traviata - Opera in three acts (1992 Digital Remaster), Act II: Alfredo! Voi! Giuseppe Verdi'
# (387, 'Electrotherapy from The Caretakers', 'Elmer Bernstein')
# Searching for "Electrotherapy from The Caretakers" by Elmer Bernstein...
# No results found for: 'Electrotherapy from The Caretakers Elmer Bernstein'
# (388, 'Deixa O Menino Brincar', 'Jorge Ben Jor')
# Searching for "Deixa O Menino Brincar" by Jorge Ben Jor...
# Done.
# (389, "What a Girl Can't Do", 'The Hangmen')
# Searching for "What a Girl Can't Do" by The Hangmen...
# Done.
# (390, 'Hey-Da-Da-Dow', 'The Dolphins')
# Searching for "Hey-Da-Da-Dow" by The Dolphins...
# No results found for: 'Hey-Da-Da-Dow The Dolphins'
# (391, 'Out Of This World', 'Gerald Wilson Orchestra')
# Searching for "Out Of This World" by Gerald Wilson Orchestra...
# Done.
# (392, 'Madama Butterfly (1986 - Remaster), Act I: Vogliatemi bene, un bene piccolino (Pinkerton/Butterfly)', 'Giacomo Puccini')
# Searching for "Madama Butterfly (1986 - Remaster), Act I: Vogliatemi bene, un bene piccolino (Pinkerton/Butterfly)" by Giacomo Puccini...
# No results found for: 'Madama Butterfly (1986 - Remaster), Act I: Vogliatemi bene, un bene piccolino (Pinkerton/Butterfly) Giacomo Puccini'
# (393, 'A Solitude', 'Denise Levertov')
# Searching for "A Solitude" by Denise Levertov...
# Done.
# (394, 'Our Time for Loving', 'Harry Belafonte')
# Searching for "Our Time for Loving" by Harry Belafonte...
# Done.
# (395, 'O Diamante Cor de Rosa - Versão remasterizada', 'Roberto Carlos')
# Searching for "O Diamante Cor de Rosa - Versão remasterizada" by Roberto Carlos...
# No results found for: 'O Diamante Cor de Rosa - Versão remasterizada Roberto Carlos'
# (396, 'Ruby Ann', 'Marty Robbins')
# Searching for "Ruby Ann" by Marty Robbins...
# Done.
# (397, 'Do Wah Diddy Diddy', 'Manfred Mann')
# Searching for "Do Wah Diddy Diddy" by Manfred Mann...
# Done.
# (398, 'Flamenco Revolucionario', 'Chicho Sánchez Ferlosio')
# Searching for "Flamenco Revolucionario" by Chicho Sánchez Ferlosio...
# No results found for: 'Flamenco Revolucionario Chicho Sánchez Ferlosio'
# (399, 'Room Full Of Tears', 'The Drifters')
# Searching for "Room Full Of Tears" by The Drifters...
# Done.
# (400, 'If I Were A Carpenter', 'Four Tops')
# Searching for "If I Were A Carpenter" by Four Tops...
# Done.
# (401, 'Reza', 'Elvin Jones')
# Searching for "Reza" by Elvin Jones...
# Done.
# (402, 'Mecca', 'Gene Pitney')
# Searching for "Mecca" by Gene Pitney...
# Done.
# (403, 'Not So Sweet Martha Lorraine', 'Country Joe & The Fish')
# Searching for "Not So Sweet Martha Lorraine" by Country Joe & The Fish...
# Done.
# (404, 'Oye Cómo Va', 'Tito Puente')
# Searching for "Oye Cómo Va" by Tito Puente...
# Done.
# (405, 'Apologize', 'Ed Ames')
# Searching for "Apologize" by Ed Ames...
# Done.
# (406, 'Candy', 'The Astors')
# Searching for "Candy" by The Astors...
# Done.
# (407, 'Me Deixe em Paz (You Better Move On)', 'Leño')
# Searching for "Me Deixe em Paz (You Better Move On)" by Leño...
# Done.
# (408, 'Não Vá Se Perder Por Aí', 'Os Mutantes')
# Searching for "Não Vá Se Perder Por Aí" by Os Mutantes...
# Done.
# (409, 'Arietis - Remastered', 'Freddie Hubbard')
# Searching for "Arietis - Remastered" by Freddie Hubbard...
# No results found for: 'Arietis - Remastered Freddie Hubbard'
# (410, 'Rapaz da Moda / Quem Te Viu, Quem Te Vê', 'Peter Thomas')
# Searching for "Rapaz da Moda / Quem Te Viu, Quem Te Vê" by Peter Thomas...
# Done.
# (411, 'A Praça É Do Povo', 'Sérgio Ricardo')
# Searching for "A Praça É Do Povo" by Sérgio Ricardo...
# Done.
# (412, 'Tristeza', 'Orlando Silva')
# Searching for "Tristeza" by Orlando Silva...
# Done.
# (413, 'International Danger', 'Peter Thomas')
# Searching for "International Danger" by Peter Thomas...
# Done.
# (414, 'True Love Goes On And On', 'Burl Ives')
# Searching for "True Love Goes On And On" by Burl Ives...
# Done.
# (415, "Walkin' Back To Happiness", 'Helen Shapiro')
# Searching for "Walkin' Back To Happiness" by Helen Shapiro...
# Done.
# (416, 'Cumbiando', 'Tito Puente')
# Searching for "Cumbiando" by Tito Puente...
# Done.
# (417, "Don't You Care", 'The Buckinghams')
# Searching for "Don't You Care" by The Buckinghams...
# Done.
# (418, 'Stronger', 'The Hippy Boys')
# Searching for "Stronger" by The Hippy Boys...
# Done.
# (419, 'Paris In The Spring', 'Elmer Bernstein')
# Searching for "Paris In The Spring" by Elmer Bernstein...
# Done.
# (420, 'Uncle Meat: Main Title Theme', 'Frank Zappa')
# Searching for "Uncle Meat: Main Title Theme" by Frank Zappa...
# Done.
# (421, "La Dama D'Arago", 'Joan Manuel Serrat')
# Searching for "La Dama D'Arago" by Joan Manuel Serrat...
# Done.
# (422, 'Lonely Winds', 'The Drifters')
# Searching for "Lonely Winds" by The Drifters...
# Done.
# (423, 'Postcard - 2007 Remaster', 'The Bonzo Dog Band')
# Searching for "Postcard - 2007 Remaster" by The Bonzo Dog Band...
# No results found for: 'Postcard - 2007 Remaster The Bonzo Dog Band'
# (424, "'Til", 'The Angels')
# Searching for "'Til" by The Angels...
# Done.
# (425, 'Carmen: Act I - "Hier die Order!"', 'Leipzig Radio Symphony Orchestra')
# Searching for "Carmen: Act I - "Hier die Order!"" by Leipzig Radio Symphony Orchestra...
# Done.
# (426, 'Big Boss Man', 'Elvis Presley')
# Searching for "Big Boss Man" by Elvis Presley...
# Done.
# (427, 'The Sound Of Music - 2007 Remastered Version', 'The Bonzo Dog Band')
# Searching for "The Sound Of Music - 2007 Remastered Version" by The Bonzo Dog Band...
# No results found for: 'The Sound Of Music - 2007 Remastered Version The Bonzo Dog Band'
# (428, 'Funky Street', 'Arthur Conley')
# Searching for "Funky Street" by Arthur Conley...
# Done.
# (429, 'The Chrome Plated Megaphone Of Destiny', 'Frank Zappa')
# Searching for "The Chrome Plated Megaphone Of Destiny" by Frank Zappa...
# Done.
# (430, 'Help Me Girl', 'Eric Burdon & The Animals')
# Searching for "Help Me Girl" by Eric Burdon & The Animals...
# Done.
# (431, 'Gente', 'Garoto')
# Searching for "Gente" by Garoto...
# Done.
# (432, "I Just Don't Understand", 'Ann-Margret')
# Searching for "I Just Don't Understand" by Ann-Margret...
# Done.
# (433, "Celebrated Walkin' Blues", 'Taj Mahal')
# Searching for "Celebrated Walkin' Blues" by Taj Mahal...
# Done.
# (434, 'Todo Amor Eu Lhe DareI', 'Trio Melodia')
# Searching for "Todo Amor Eu Lhe DareI" by Trio Melodia...
# No results found for: 'Todo Amor Eu Lhe DareI Trio Melodia'
# (435, 'In Like Flint: End Titles (Your Zowie Face) - From "In Like Flint"', 'Jerry Goldsmith')
# Searching for "In Like Flint: End Titles (Your Zowie Face) - From "In Like Flint"" by Jerry Goldsmith...
# No results found for: 'In Like Flint: End Titles (Your Zowie Face) - From "In Like Flint" Jerry Goldsmith'
# (436, 'The Push And Kick', 'Mark Valentino')
# Searching for "The Push And Kick" by Mark Valentino...
# Done.
# (437, 'Along The Santa Fe Trail', 'Clint Eastwood')
# Searching for "Along The Santa Fe Trail" by Clint Eastwood...
# Done.
# (438, 'La Vie En Rose', 'Elmer Bernstein')
# Searching for "La Vie En Rose" by Elmer Bernstein...
# No results found for: 'La Vie En Rose Elmer Bernstein'
# (439, 'Nearer To You', 'Betty Harris')
# Searching for "Nearer To You" by Betty Harris...
# Done.
# (440, 'Fe de Vida', 'Joan Manuel Serrat')
# Searching for "Fe de Vida" by Joan Manuel Serrat...
# Done.
# (441, 'Show Business', 'Lou Rawls')
# Searching for "Show Business" by Lou Rawls...
# Done.
# (442, 'Life', 'Sly & The Family Stone')
# Searching for "Life" by Sly & The Family Stone...
# Done.
# (443, "He'll Have To Go", 'Solomon Burke')
# Searching for "He'll Have To Go" by Solomon Burke...
# Done.
# (444, 'Bandit Of My Dreams', 'Eddie Hodges')
# Searching for "Bandit Of My Dreams" by Eddie Hodges...
# Done.
# (445, 'The trio - Il triello', 'Ennio Morricone')
# Searching for "The trio - Il triello" by Ennio Morricone...
# Done.
# (446, 'He Knows I Love Him Too Much', 'The Paris Sisters')
# Searching for "He Knows I Love Him Too Much" by The Paris Sisters...
# Done.
# (447, 'Tango per un pianista virtuoso', 'Giampiero Boneschi')
# Searching for "Tango per un pianista virtuoso" by Giampiero Boneschi...
# No results found for: 'Tango per un pianista virtuoso Giampiero Boneschi'
# (448, 'Grazing In The Grass', 'The Friends Of Distinction')
# Searching for "Grazing In The Grass" by The Friends Of Distinction...
# Done.
# (449, 'House Of The Rising Sun', 'The Animals')
# Searching for "House Of The Rising Sun" by The Animals...
# Searching for "House Of The Rising Sun" by The Animals...
# Searching for "House Of The Rising Sun" by The Animals...
# Done.
# (450, 'Here Rattler Here', 'Harry Belafonte')
# Searching for "Here Rattler Here" by Harry Belafonte...
# Done.
# (451, 'Where Do You Go', 'Cher')
# Searching for "Where Do You Go" by Cher...
# Done.
# (452, 'Gee', 'Jan & Dean')
# Searching for "Gee" by Jan & Dean...
# Done.
# (453, "La fille du régiment / Act 2: C'en est donc fait, en mon sort va changer", 'Gaetano Donizetti')
# Searching for "La fille du régiment / Act 2: C'en est donc fait, en mon sort va changer" by Gaetano Donizetti...
# No results found for: 'La fille du régiment / Act 2: C'en est donc fait, en mon sort va changer Gaetano Donizetti'
# (454, 'Warmed Over Kisses (Left Over Love)', 'Brian Hyland')
# Searching for "Warmed Over Kisses (Left Over Love)" by Brian Hyland...
# Done.
# (455, 'Part Two', 'Frank Zappa')
# Searching for "Part Two" by Frank Zappa...
# Done.
# (456, 'Sit Down, I Think I Love You', 'The Mojo Men')
# Searching for "Sit Down, I Think I Love You" by The Mojo Men...
# Done.
# (457, 'Baby Come Home', 'Ruby And The Romantics')
# Searching for "Baby Come Home" by Ruby And The Romantics...
# Done.
# (458, 'Wear Your Love Like Heaven', 'Donovan')
# Searching for "Wear Your Love Like Heaven" by Donovan...
# Done.
# (459, 'Listen People', "Herman's Hermits")
# Searching for "Listen People" by Herman's Hermits...
# Done.
# (460, 'A Woman Like You', 'Bert Jansch')
# Searching for "A Woman Like You" by Bert Jansch...
# Done.
# (461, 'Chove Chuva', 'Jorge Ben Jor')
# Searching for "Chove Chuva" by Jorge Ben Jor...
# Done.
# (462, "My Boomerang Won't Come Back", 'Charlie Drake')
# Searching for "My Boomerang Won't Come Back" by Charlie Drake...
# Done.
# (463, 'A Day In The Life Of A Fool', 'Jack Jones')
# Searching for "A Day In The Life Of A Fool" by Jack Jones...
# Done.
# (464, 'Si un Dia Vols', 'Raimon')
# Searching for "Si un Dia Vols" by Raimon...
# Done.
# (465, 'Dear John C.', 'Elvin Jones')
# Searching for "Dear John C." by Elvin Jones...
# Done.
# (466, "I'm A Man", 'The Yardbirds')
# Searching for "I'm A Man" by The Yardbirds...
# Done.
# (467, "Lovey Dovey Kinda Lovin'", 'Brenton Wood')
# Searching for "Lovey Dovey Kinda Lovin'" by Brenton Wood...
# Done.
# (468, '...And Then There Were Drums', 'Sandy Nelson')
# Searching for "...And Then There Were Drums" by Sandy Nelson...
# Specified song does not contain lyrics. Rejecting.
# (469, 'Once Again (Outra Vez)', 'Antônio Carlos Jobim')
# Searching for "Once Again (Outra Vez)" by Antônio Carlos Jobim...
# Done.
# (470, 'Rigoletto: Act II: Tutte le feste', 'Giuseppe Verdi')
# Searching for "Rigoletto: Act II: Tutte le feste" by Giuseppe Verdi...
# No results found for: 'Rigoletto: Act II: Tutte le feste Giuseppe Verdi'
# (471, 'Es Mentira', 'Tito Puente')
# Searching for "Es Mentira" by Tito Puente...
# Done.
# (472, 'Let The Good Times Roll & Feel So Good', 'Bunny Sigler')
# Searching for "Let The Good Times Roll & Feel So Good" by Bunny Sigler...
# Done.
# (473, 'Ingrato Amor', 'Vicente Fernández')
# Searching for "Ingrato Amor" by Vicente Fernández...
# Done.
# (474, 'Amen', 'Otis Redding')
# Searching for "Amen" by Otis Redding...
# Done.
# (475, "If I Didn't Love You", 'Chuck Jackson')
# Searching for "If I Didn't Love You" by Chuck Jackson...
# Done.
# (476, 'Summertime, Summertime', 'The Jamies')
# Searching for "Summertime, Summertime" by The Jamies...
# Done.
# (477, 'Bossa girotondo', 'Benedetto Ghiglia')
# Searching for "Bossa girotondo" by Benedetto Ghiglia...
# No results found for: 'Bossa girotondo Benedetto Ghiglia'
# (478, "My Balloon's Going Up", 'Archie Bell & The Drells')
# Searching for "My Balloon's Going Up" by Archie Bell & The Drells...
# Done.
# (479, 'Rain', 'The Beatles')
# Searching for "Rain" by The Beatles...
# Done.
# (480, "He's So Fine", 'The Chiffons')
# Searching for "He's So Fine" by The Chiffons...
# Done.
# (481, 'A Bailar Pachanga', 'Tito Puente')
# Searching for "A Bailar Pachanga" by Tito Puente...
# Done.
# (482, 'Only You Can Do It - Remastered', 'Françoise Hardy')
# Searching for "Only You Can Do It - Remastered" by Françoise Hardy...
# Done.
# (483, 'Weihnachtslieder: Mater et filia', 'Traditional')
# Searching for "Weihnachtslieder: Mater et filia" by Traditional...
# No results found for: 'Weihnachtslieder: Mater et filia Traditional'
# (484, 'Me Recordarás', 'Javier Solís')
# Searching for "Me Recordarás" by Javier Solís...
# Done.
# (485, 'Yesterlove', 'Gerald Wilson Orchestra')
# Searching for "Yesterlove" by Gerald Wilson Orchestra...
# No results found for: 'Yesterlove Gerald Wilson Orchestra'
# (486, 'Dedicated To The One I Love', 'The Mamas & The Papas')
# Searching for "Dedicated To The One I Love" by The Mamas & The Papas...
# Done.
# (487, 'Preludietto, fughetta e finalino 2', 'Ennio Morricone')
# Searching for "Preludietto, fughetta e finalino 2" by Ennio Morricone...
# No results found for: 'Preludietto, fughetta e finalino 2 Ennio Morricone'
# (488, "Don't You Believe It", 'Andy Williams')
# Searching for "Don't You Believe It" by Andy Williams...
# Done.
# (489, 'Lady', 'Jack Jones')
# Searching for "Lady" by Jack Jones...
# Done.
# (490, 'Godaari Gattundi', 'P. Susheela')
# Searching for "Godaari Gattundi" by P. Susheela...
# No results found for: 'Godaari Gattundi P. Susheela'
# (491, 'Carmen Suite No. 1: Les Toréadors. Allegro giocoso (Introduction to Act I)', 'National Philharmonic Orchestra')
# Searching for "Carmen Suite No. 1: Les Toréadors. Allegro giocoso (Introduction to Act I)" by National Philharmonic Orchestra...
# No results found for: 'Carmen Suite No. 1: Les Toréadors. Allegro giocoso (Introduction to Act I) National Philharmonic Orchestra'
# (492, 'Main Title', 'Jerry Goldsmith')
# Searching for "Main Title" by Jerry Goldsmith...
# Specified song does not contain lyrics. Rejecting.
# (493, 'Eterna Navidad', 'La Sonora Matancera')
# Searching for "Eterna Navidad" by La Sonora Matancera...
# No results found for: 'Eterna Navidad La Sonora Matancera'
# (494, 'Crazy Downtown', 'Allan Sherman')
# Searching for "Crazy Downtown" by Allan Sherman...
# Done.
# (495, "Where You're At", 'Ultimate Spinach')
# Searching for "Where You're At" by Ultimate Spinach...
# Done.
# (496, 'Unchained Melody', 'Vito & The Salutations')
# Searching for "Unchained Melody" by Vito & The Salutations...
# Done.
# (497, 'Ninna Nanna per Lisa', 'Maurice Jarre')
# Searching for "Ninna Nanna per Lisa" by Maurice Jarre...
# Done.
# (498, 'Serenade in G Major, K. 525 "Eine kleine Nachtmusik": II. Romance. Andante', 'Wolfgang Amadeus Mozart')
# Searching for "Serenade in G Major, K. 525 "Eine kleine Nachtmusik": II. Romance. Andante" by Wolfgang Amadeus Mozart...
# No results found for: 'Serenade in G Major, K. 525 "Eine kleine Nachtmusik": II. Romance. Andante Wolfgang Amadeus Mozart'
# (499, 'How Many Teardrops', 'Lou Christie')
# Searching for "How Many Teardrops" by Lou Christie...
# Done.
# (500, "Il Mercenario (L' Arena)", 'Ennio Morricone')
# Searching for "Il Mercenario (L' Arena)" by Ennio Morricone...
# Specified song does not contain lyrics. Rejecting.
# (501, "We Got A Thing That's In The Groove", 'The Capitols')
# Searching for "We Got A Thing That's In The Groove" by The Capitols...
# Done.
# (502, 'Little Band Of Gold', 'James Gilreath')
# Searching for "Little Band Of Gold" by James Gilreath...
# Done.
# (503, 'Glad To Be Unhappy', 'The Mamas & The Papas')
# Searching for "Glad To Be Unhappy" by The Mamas & The Papas...
# Done.
# (504, 'Like A Rolling Stone', 'Bob Dylan')
# Searching for "Like A Rolling Stone" by Bob Dylan...
# Searching for "Like A Rolling Stone" by Bob Dylan...
# Done.
# (505, 'Away in a Manger - Remastered 1997', 'Traditional')
# Searching for "Away in a Manger - Remastered 1997" by Traditional...
# Done.
# (506, "L'eclisse 12", 'Giovanni Fusco')
# Searching for "L'eclisse 12" by Giovanni Fusco...
# No results found for: 'L'eclisse 12 Giovanni Fusco'
# (507, 'Day Tripper', 'The Beatles')
# Searching for "Day Tripper" by The Beatles...
# Done.
# (508, 'Five Brothers', 'Marty Robbins')
# Searching for "Five Brothers" by Marty Robbins...
# Done.
# (509, 'April In Paris', 'Elmer Bernstein')
# Searching for "April In Paris" by Elmer Bernstein...
# No results found for: 'April In Paris Elmer Bernstein'
# (510, 'Carmen: Act I - "Draussen am Wall von Sevilla"', 'Leipzig Radio Symphony Orchestra')
# Searching for "Carmen: Act I - "Draussen am Wall von Sevilla"" by Leipzig Radio Symphony Orchestra...
# No results found for: 'Carmen: Act I - "Draussen am Wall von Sevilla" Leipzig Radio Symphony Orchestra'
# (511, 'Angelica', 'Scott Walker')
# Searching for "Angelica" by Scott Walker...
# Done.
# (512, 'Mad Man Blues', 'Silver Apples')
# Searching for "Mad Man Blues" by Silver Apples...
# Done.
# (513, 'The Reporter', 'Alan Hawkshaw')
# Searching for "The Reporter" by Alan Hawkshaw...
# No results found for: 'The Reporter Alan Hawkshaw'
# (514, "I Can't Dance To That Music You're Playin'", 'Martha Reeves & The Vandellas')
# Searching for "I Can't Dance To That Music You're Playin'" by Martha Reeves & The Vandellas...
# Done.
# (515, 'Amore mio aiutami - Version 6', 'Piero Piccioni')
# Searching for "Amore mio aiutami - Version 6" by Piero Piccioni...
# Done.
# (516, 'Rajaavin Paarvai', 'P. Susheela')
# Searching for "Rajaavin Paarvai" by P. Susheela...
# No results found for: 'Rajaavin Paarvai P. Susheela'
# (517, 'Weaver Of Dreams - Remastered 2003/Rudy Van Gelder Edition', 'Freddie Hubbard')
# Searching for "Weaver Of Dreams - Remastered 2003/Rudy Van Gelder Edition" by Freddie Hubbard...
# No results found for: 'Weaver Of Dreams - Remastered 2003/Rudy Van Gelder Edition Freddie Hubbard'
# (518, 'Pauvre Moi, Pauvre Moi (Poor Me, Poor Me)', 'Elmer Bernstein')
# Searching for "Pauvre Moi, Pauvre Moi (Poor Me, Poor Me)" by Elmer Bernstein...
# No results found for: 'Pauvre Moi, Pauvre Moi (Poor Me, Poor Me) Elmer Bernstein'
# (519, 'The More I See You', 'Chris Montez')
# Searching for "The More I See You" by Chris Montez...
# Done.
# (520, 'Échame a Mí la Culpa', 'Amalia Mendoza')
# Searching for "Échame a Mí la Culpa" by Amalia Mendoza...
# Done.
# (521, 'Nachrichten aus Cannabistan', 'Amon Düül')
# Searching for "Nachrichten aus Cannabistan" by Amon Düül...
# No results found for: 'Nachrichten aus Cannabistan Amon Düül'
# (522, "Sue's Gotta Be Mine", 'Del Shannon')
# Searching for "Sue's Gotta Be Mine" by Del Shannon...
# Done.
# (523, 'Mama Said', 'The Shirelles')
# Searching for "Mama Said" by The Shirelles...
# Done.
# (524, 'Spanish Flea', 'Herb Alpert & The Tijuana Brass')
# Searching for "Spanish Flea" by Herb Alpert & The Tijuana Brass...
# Specified song does not contain lyrics. Rejecting.
# (525, 'Le tourbillon', 'Georges Delerue')
# Searching for "Le tourbillon" by Georges Delerue...
# Done.
# (526, 'Listen To The Band', 'The Monkees')
# Searching for "Listen To The Band" by The Monkees...
# Done.
# (527, 'Los decorados', 'Patxi Andion')
# Searching for "Los decorados" by Patxi Andion...
# No results found for: 'Los decorados Patxi Andion'
# (528, 'Générique', 'André Hossein')
# Searching for "Générique" by André Hossein...
# Done.
# (529, 'Time', 'Pozo Seco Singers')
# Searching for "Time" by Pozo Seco Singers...
# Done.
# (530, 'The Flying Dutchman, Act I: Overture', 'Staatskapelle Berlin')
# Searching for "The Flying Dutchman, Act I: Overture" by Staatskapelle Berlin...
# No results found for: 'The Flying Dutchman, Act I: Overture Staatskapelle Berlin'
# (531, '4 Dance Episodes from Rodeo: IV. Hoe Down', 'Aaron Copland')
# Searching for "4 Dance Episodes from Rodeo: IV. Hoe Down" by Aaron Copland...
# No results found for: '4 Dance Episodes from Rodeo: IV. Hoe Down Aaron Copland'
# (532, "Cathy's Clown", 'The Everly Brothers')
# Searching for "Cathy's Clown" by The Everly Brothers...
# Done.
# (533, 'Rigoletto [Act I]: Pari siamo! (Rigoletto)', 'Giuseppe Verdi')
# Searching for "Rigoletto [Act I]: Pari siamo! (Rigoletto)" by Giuseppe Verdi...
# No results found for: 'Rigoletto [Act I]: Pari siamo! (Rigoletto) Giuseppe Verdi'
# (534, "I'm Comin' On On Back To You", 'Jackie Wilson')
# Searching for "I'm Comin' On On Back To You" by Jackie Wilson...
# Done.
# (535, 'Thank You Baby', 'The Shirelles')
# Searching for "Thank You Baby" by The Shirelles...
# Done.
# (536, 'A Man And The Blues', 'Buddy Guy')
# Searching for "A Man And The Blues" by Buddy Guy...
# Done.
# (537, 'Maria (Me Perdoa Maria)', 'Gilberto Gil')
# Searching for "Maria (Me Perdoa Maria)" by Gilberto Gil...
# Done.
# (538, 'If I Were A Carpenter', 'Bobby Darin')
# Searching for "If I Were A Carpenter" by Bobby Darin...
# Done.
# (539, 'Somebody To Love', 'Jefferson Airplane')
# Searching for "Somebody To Love" by Jefferson Airplane...
# Done.
# (540, 'A Joan Miró - En Directe', 'Raimon')
# Searching for "A Joan Miró - En Directe" by Raimon...
# Done.
# (541, "There's No Other (Like My Baby)", 'The Crystals')
# Searching for "There's No Other (Like My Baby)" by The Crystals...
# Done.
# (542, 'Wonderful Summer', 'Robin Ward')
# Searching for "Wonderful Summer" by Robin Ward...
# Done.
# (543, 'Faded Love', 'Patsy Cline')
# Searching for "Faded Love" by Patsy Cline...
# Done.
# (544, 'Carnival of the Animals, R. 125: The Elephant', 'Camille Saint-Saëns')
# Searching for "Carnival of the Animals, R. 125: The Elephant" by Camille Saint-Saëns...
# No results found for: 'Carnival of the Animals, R. 125: The Elephant Camille Saint-Saëns'
# (545, 'Before And After', 'Chad & Jeremy')
# Searching for "Before And After" by Chad & Jeremy...
# Done.
# (546, 'Billy the Kid Suite: IV. Prairie Night. Card Game at Night', 'Aaron Copland')
# Searching for "Billy the Kid Suite: IV. Prairie Night. Card Game at Night" by Aaron Copland...
# No results found for: 'Billy the Kid Suite: IV. Prairie Night. Card Game at Night Aaron Copland'
# (547, 'Oceanic Beloved', 'Alice Coltrane')
# Searching for "Oceanic Beloved" by Alice Coltrane...
# Specified song does not contain lyrics. Rejecting.
# (548, 'More', 'Vic Dana')
# Searching for "More" by Vic Dana...
# Done.
# (549, "I Don't Want To Cry", 'Chuck Jackson')
# Searching for "I Don't Want To Cry" by Chuck Jackson...
# Done.
# (550, 'The James Bond Theme', 'Billy Strange')
# Searching for "The James Bond Theme" by Billy Strange...
# Done.
# (551, 'Sombras de la China', 'Joan Manuel Serrat')
# Searching for "Sombras de la China" by Joan Manuel Serrat...
# Done.
# (552, 'Her Royal Majesty', 'James Darren')
# Searching for "Her Royal Majesty" by James Darren...
# Done.
# (553, 'Desesperadamente', 'Eydie Gormé')
# Searching for "Desesperadamente" by Eydie Gormé...
# Done.
# (554, 'Subterranean Homesick Blues', 'Bob Dylan')
# Searching for "Subterranean Homesick Blues" by Bob Dylan...
# Done.
# (555, 'Never Comes The Day', 'The Moody Blues')
# Searching for "Never Comes The Day" by The Moody Blues...
# Done.
# (556, 'Little Boxes', 'Pete Seeger')
# Searching for "Little Boxes" by Pete Seeger...
# Done.
# (557, 'The Face of the Bass', 'Ornette Coleman')
# Searching for "The Face of the Bass" by Ornette Coleman...
# Specified song does not contain lyrics. Rejecting.
# (558, 'Prelude (Reprise)', 'Elmer Bernstein')
# Searching for "Prelude (Reprise)" by Elmer Bernstein...
# No results found for: 'Prelude (Reprise) Elmer Bernstein'
# (559, 'Ao Entardecer (Deep Purple)', 'Leño')
# Searching for "Ao Entardecer (Deep Purple)" by Leño...
# No results found for: 'Ao Entardecer (Deep Purple) Leño'
# (560, 'Sorry Suzanne', 'The Hollies')
# Searching for "Sorry Suzanne" by The Hollies...
# Done.
# (561, "Trampin'", 'Traditional')
# Searching for "Trampin'" by Traditional...
# Done.
# (562, 'Vinthoothar', 'Jolly Abraham')
# Searching for "Vinthoothar" by Jolly Abraham...
# No results found for: 'Vinthoothar Jolly Abraham'
# (563, 'Mercy, Mercy, Mercy', 'Cannonball Adderley')
# Searching for "Mercy, Mercy, Mercy" by Cannonball Adderley...
# Done.
# (564, 'O Velho Homem do Mar - Versão remasterizada', 'Roberto Carlos')
# Searching for "O Velho Homem do Mar - Versão remasterizada" by Roberto Carlos...
# No results found for: 'O Velho Homem do Mar - Versão remasterizada Roberto Carlos'
# (565, 'Stand By Your Man', 'Tammy Wynette')
# Searching for "Stand By Your Man" by Tammy Wynette...
# Done.
# (566, 'Underwater', 'The Frogmen')
# Searching for "Underwater" by The Frogmen...
# Done.
# (567, 'In Epiphania Domini. Graduale: Omnes de Saba, V Mode', 'Traditional')
# Searching for "In Epiphania Domini. Graduale: Omnes de Saba, V Mode" by Traditional...
# Done.
# (568, 'Snap Your Fingers', 'Barbara Lewis')
# Searching for "Snap Your Fingers" by Barbara Lewis...
# Done.
# (569, 'Walk Away Renee', 'The Left Banke')
# Searching for "Walk Away Renee" by The Left Banke...
# Done.
# (570, 'Badge', 'Cream')
# Searching for "Badge" by Cream...
# Done.
# (571, 'Do You Mind?', 'Anthony Newley')
# Searching for "Do You Mind?" by Anthony Newley...
# Done.
# (572, 'Winter Song', 'Nico')
# Searching for "Winter Song" by Nico...
# Done.
# (573, 'Driving Wheel', 'Junior Parker')
# Searching for "Driving Wheel" by Junior Parker...
# Done.
# (574, 'Madama Butterfly, Act II: Un bel dì vedremo (Butterfly)', 'Giacomo Puccini')
# Searching for "Madama Butterfly, Act II: Un bel dì vedremo (Butterfly)" by Giacomo Puccini...
# No results found for: 'Madama Butterfly, Act II: Un bel dì vedremo (Butterfly) Giacomo Puccini'
# (575, 'Make Me Forget', 'Bobby Rydell')
# Searching for "Make Me Forget" by Bobby Rydell...
# Done.
# (576, "It's All Right (You're Just In Love)", 'The Tams')
# Searching for "It's All Right (You're Just In Love)" by The Tams...
# Done.
# (577, "They Ballin' Me Name", 'King Fighter')
# Searching for "They Ballin' Me Name" by King Fighter...
# Done.
# (578, 'Boss-Eyed Whelk', 'Johnny Pearson')
# Searching for "Boss-Eyed Whelk" by Johnny Pearson...
# No results found for: 'Boss-Eyed Whelk Johnny Pearson'
# (579, 'Leopard-Skin Pill-Box Hat', 'Bob Dylan')
# Searching for "Leopard-Skin Pill-Box Hat" by Bob Dylan...
# Done.
# (580, 'Bally Mena', 'Harry Belafonte')
# Searching for "Bally Mena" by Harry Belafonte...
# Done.
# (581, 'The Tracks Of My Tears', 'Johnny Rivers')
# Searching for "The Tracks Of My Tears" by Johnny Rivers...
# Done.
# (582, 'Right Or Wrong', 'Ronnie Dove')
# Searching for "Right Or Wrong" by Ronnie Dove...
# Done.
# (583, 'I Apologize', 'Timi Yuro')
# Searching for "I Apologize" by Timi Yuro...
# Done.
# (584, 'You Better Get It', 'Joe Tex')
# Searching for "You Better Get It" by Joe Tex...
# Done.
# (585, 'Mercy, Mercy, Mercy', 'Marlena Shaw')
# Searching for "Mercy, Mercy, Mercy" by Marlena Shaw...
# Done.
# (586, 'Sweetest One', 'The Metros')
# Searching for "Sweetest One" by The Metros...
# Done.
# (587, 'Vereda Tropical', 'Eydie Gormé')
# Searching for "Vereda Tropical" by Eydie Gormé...
# Done.
# (588, 'Sobre Las Olas', 'Vicente Fernández')
# Searching for "Sobre Las Olas" by Vicente Fernández...
# Done.
# (589, 'Little Green Apples', 'O.C. Smith')
# Searching for "Little Green Apples" by O.C. Smith...
# Done.
# (590, 'Lucille', 'The Everly Brothers')
# Searching for "Lucille" by The Everly Brothers...
# Done.
# (591, 'Confession au clair de lune', 'Georges Delerue')
# Searching for "Confession au clair de lune" by Georges Delerue...
# Specified song does not contain lyrics. Rejecting.
# (592, 'Dirty Man', 'Laura Lee')
# Searching for "Dirty Man" by Laura Lee...
# Done.
# (593, 'Qué Saco Rogar al Cielo', 'Victor Jara')
# Searching for "Qué Saco Rogar al Cielo" by Victor Jara...
# Done.
# (594, 'Somewhere', 'Len Barry')
# Searching for "Somewhere" by Len Barry...
# Done.
# (595, "O Sol Se Põe no Horizonte ( I'll be On My Way)", 'Leno e Lilian')
# Searching for "O Sol Se Põe no Horizonte ( I'll be On My Way)" by Leno e Lilian...
# No results found for: 'O Sol Se Põe no Horizonte ( I'll be On My Way) Leno e Lilian'
# (596, 'Party In The Ward from The Caretakers', 'Elmer Bernstein')
# Searching for "Party In The Ward from The Caretakers" by Elmer Bernstein...
# No results found for: 'Party In The Ward from The Caretakers Elmer Bernstein'
# (597, 'Hurdy Gurdy Man', 'Donovan')
# Searching for "Hurdy Gurdy Man" by Donovan...
# Done.
# (598, 'I Wanna Be Around', 'Tony Bennett')
# Searching for "I Wanna Be Around" by Tony Bennett...
# Done.
# (599, 'Come Go With Me', 'Dion')
# Searching for "Come Go With Me" by Dion...
# Done.
# (600, 'La recherche, pt. 2', 'Vladimir Cosma')
# Searching for "La recherche, pt. 2" by Vladimir Cosma...
# Done.
# (601, 'La fille du régiment / Act 1: Le camarade est amoureux!', 'Gaetano Donizetti')
# Searching for "La fille du régiment / Act 1: Le camarade est amoureux!" by Gaetano Donizetti...
# No results found for: 'La fille du régiment / Act 1: Le camarade est amoureux! Gaetano Donizetti'
# (602, 'Zamba del "Che"', 'Victor Jara')
# Searching for "Zamba del "Che"" by Victor Jara...
# Done.
# (603, "Two Weeks Since You've Gone", 'Scott Walker')
# Searching for "Two Weeks Since You've Gone" by Scott Walker...
# Done.
# (604, 'A Corner In The Sun', 'Walter Jackson')
# Searching for "A Corner In The Sun" by Walter Jackson...
# Done.
# (605, "Walkin' In The Sunshine", 'Roger Miller')
# Searching for "Walkin' In The Sunshine" by Roger Miller...
# Done.
# (606, 'The Unknown Soldier', 'The Doors')
# Searching for "The Unknown Soldier" by The Doors...
# Done.
# (607, 'Allá en el Baile Grande', 'Los Relampagos Del Norte')
# Searching for "Allá en el Baile Grande" by Los Relampagos Del Norte...
# No results found for: 'Allá en el Baile Grande Los Relampagos Del Norte'
# (608, 'Cantarem la Vida', 'Raimon')
# Searching for "Cantarem la Vida" by Raimon...
# Done.
# (609, "(Say) You're My Girl", 'Roy Orbison')
# Searching for "(Say) You're My Girl" by Roy Orbison...
# Done.
# (610, 'Ice Cream Song', 'The Dynamics')
# Searching for "Ice Cream Song" by The Dynamics...
# Done.
# (611, 'Endhan Yesuve Undhan Nesame', 'Sister Sarah Navaroji')
# Searching for "Endhan Yesuve Undhan Nesame" by Sister Sarah Navaroji...
# No results found for: 'Endhan Yesuve Undhan Nesame Sister Sarah Navaroji'
# (612, "I'm Gonna Make You Mine", 'Lou Christie')
# Searching for "I'm Gonna Make You Mine" by Lou Christie...
# Done.
# (613, 'In My Little Corner Of The World', 'Anita Bryant')
# Searching for "In My Little Corner Of The World" by Anita Bryant...
# Done.
# (614, "Lovin' Things", 'The Grass Roots')
# Searching for "Lovin' Things" by The Grass Roots...
# Done.
# (615, 'Tell Me Why', 'The Belmonts')
# Searching for "Tell Me Why" by The Belmonts...
# Done.
# (616, 'Talk Talk', 'The Music Machine')
# Searching for "Talk Talk" by The Music Machine...
# Done.
# (617, 'Why Not Tonight', 'Jimmy Hughes')
# Searching for "Why Not Tonight" by Jimmy Hughes...
# Done.
# (618, 'Too Young to Know', 'Scott Walker')
# Searching for "Too Young to Know" by Scott Walker...
# Done.
# (619, "Thème de l'inquiétude", 'André Hossein')
# Searching for "Thème de l'inquiétude" by André Hossein...
# Done.
# (620, 'Air', 'Cecil Taylor')
# Searching for "Air" by Cecil Taylor...
# Specified song does not contain lyrics. Rejecting.
# (621, 'La compapade', 'Jacques Dutronc')
# Searching for "La compapade" by Jacques Dutronc...
# ...
# Searching for "Princesita (Princess) - Remasterizado" by Enrique Guzman...
# No results found for: 'Princesita (Princess) - Remasterizado Enrique Guzman'
# (8341, 'Mango Mangüe', 'Celia Cruz')
# Searching for "Mango Mangüe" by Celia Cruz...
# Done.
# (8342, 'Love Poems: The Pure Fury / The Renewal / The Sensualists', 'Theodore Roethke')
# Searching for "Love Poems: The Pure Fury / The Renewal / The Sensualists" by Theodore Roethke...
# Done.
# (8343, 'How Many Tears', 'Bobby Vee')
# Searching for "How Many Tears" by Bobby Vee...
# Done.
# (8344, 'The Runaway', 'Lesley Frost')
# Searching for "The Runaway" by Lesley Frost...
# Done.
# (8345, 'October', 'Lesley Frost')
# Searching for "October" by Lesley Frost...
# Done.
# (8346, "L'idole des jeunes", 'Johnny Hallyday')
# Searching for "L'idole des jeunes" by Johnny Hallyday...
# Done.
# (8347, 'Marinheiro Só - Remastered 2006', 'Caetano Veloso')
# Searching for "Marinheiro Só - Remastered 2006" by Caetano Veloso...
# No results found for: 'Marinheiro Só - Remastered 2006 Caetano Veloso'
# (8348, 'Earth Angel', 'Johnny Tillotson')
# Searching for "Earth Angel" by Johnny Tillotson...
# Done.
# (8349, 'Change Partners', 'Antônio Carlos Jobim')
# Searching for "Change Partners" by Antônio Carlos Jobim...
# Done.
# (8350, 'Keep On Dancing', 'The Gentrys')
# Searching for "Keep On Dancing" by The Gentrys...
# Done.
# (8351, "Surfer's Stomp", 'The Marketts')
# Searching for "Surfer's Stomp" by The Marketts...
# Specified song does not contain lyrics. Rejecting.
# (8352, 'Chorei A Noite Inteira (The Night Is Over)', 'Jerry Adriani')
# Searching for "Chorei A Noite Inteira (The Night Is Over)" by Jerry Adriani...
# No results found for: 'Chorei A Noite Inteira (The Night Is Over) Jerry Adriani'
# (8353, 'Girl I Need You', 'The Artistics')
# Searching for "Girl I Need You" by The Artistics...
# Done.
# (8354, 'One On The House', 'Gerald Wilson Orchestra')
# Searching for "One On The House" by Gerald Wilson Orchestra...
# Searching for "One On The House" by Gerald Wilson Orchestra...
# Done.
# (8355, 'The Weight', 'Aretha Franklin')
# Searching for "The Weight" by Aretha Franklin...
# Done.
# (8356, "Reach Out I'll Be There", 'Four Tops')
# Searching for "Reach Out I'll Be There" by Four Tops...
# Done.
# (8357, 'Mesa Para Uno', 'Vicente Fernández')
# Searching for "Mesa Para Uno" by Vicente Fernández...
# Done.
# (8358, 'Symphony No. 5 in C-Sharp Minor: IV. Adagietto', 'Gustav Mahler')
# Searching for "Symphony No. 5 in C-Sharp Minor: IV. Adagietto" by Gustav Mahler...
# No results found for: 'Symphony No. 5 in C-Sharp Minor: IV. Adagietto Gustav Mahler'
# (8359, 'Ride The Wild Surf', 'Jan & Dean')
# Searching for "Ride The Wild Surf" by Jan & Dean...
# Done.
# (8360, 'What Kind Of Fool Do You Think I Am', 'Bill Deal & The Rhondels')
# Searching for "What Kind Of Fool Do You Think I Am" by Bill Deal & The Rhondels...
# Done.
# (8361, 'Titoli 2', 'Giovanni Fusco')
# Searching for "Titoli 2" by Giovanni Fusco...
# Done.
# (8362, '(You Were Made For) All My Love', 'Jackie Wilson')
# Searching for "(You Were Made For) All My Love" by Jackie Wilson...
# Done.
# (8363, 'Tres Pontas', 'Milton Nascimento')
# Searching for "Tres Pontas" by Milton Nascimento...
# Done.
# (8364, 'Gli Intoccabili: La ballata di Hank McCain - Soundtrack', 'Ennio Morricone')
# Searching for "Gli Intoccabili: La ballata di Hank McCain - Soundtrack" by Ennio Morricone...
# No results found for: 'Gli Intoccabili: La ballata di Hank McCain - Soundtrack Ennio Morricone'
# (8365, "If I Didn't Have A Dime (To Play The Jukebox)", 'Gene Pitney')
# Searching for "If I Didn't Have A Dime (To Play The Jukebox)" by Gene Pitney...
# Done.
# (8366, 'The Coventry Carol', 'Traditional')
# Searching for "The Coventry Carol" by Traditional...
# Searching for "The Coventry Carol" by Traditional...
# Done.
# (8367, 'Mr. Blue', 'The Fleetwoods')
# Searching for "Mr. Blue" by The Fleetwoods...
# Done.
# (8368, 'Les grands voiliers - Goëmons', 'Jean Prodromidès')
# Searching for "Les grands voiliers - Goëmons" by Jean Prodromidès...
# No results found for: 'Les grands voiliers - Goëmons Jean Prodromidès'
# (8369, 'Mil Violines', 'Chucho Avellanet')
# Searching for "Mil Violines" by Chucho Avellanet...
# No results found for: 'Mil Violines Chucho Avellanet'
# (8370, 'El Titiritero', 'Joan Manuel Serrat')
# Searching for "El Titiritero" by Joan Manuel Serrat...
# Done.
# (8371, 'Danny Boy', 'Andy Williams')
# Searching for "Danny Boy" by Andy Williams...
# Done.
# (8372, 'It Might As Well Rain Until September', 'Carole King')
# Searching for "It Might As Well Rain Until September" by Carole King...
# Done.
# (8373, 'O Sanctissima (O du fröhliche)', 'Traditional')
# Searching for "O Sanctissima (O du fröhliche)" by Traditional...
# No results found for: 'O Sanctissima (O du fröhliche) Traditional'
# (8374, 'Symphony No. 3 in C Minor, Op. 78 "Organ": I. Adagio', 'Camille Saint-Saëns')
# Searching for "Symphony No. 3 in C Minor, Op. 78 "Organ": I. Adagio" by Camille Saint-Saëns...
# No results found for: 'Symphony No. 3 in C Minor, Op. 78 "Organ": I. Adagio Camille Saint-Saëns'
# (8375, 'O Ultimo Tango', 'Nelson Gonçalves')
# Searching for "O Ultimo Tango" by Nelson Gonçalves...
# Done.
# (8376, "I Don't Want To Cry", 'Ruby Winters')
# Searching for "I Don't Want To Cry" by Ruby Winters...
# Done.
# (8377, 'The Christmas Song (Merry Christmas To You)', 'Nat King Cole')
# Searching for "The Christmas Song (Merry Christmas To You)" by Nat King Cole...
# Searching for "The Christmas Song (Merry Christmas To You)" by Nat King Cole...
# Searching for "The Christmas Song (Merry Christmas To You)" by Nat King Cole...
# Searching for "The Christmas Song (Merry Christmas To You)" by Nat King Cole...
# Done.
# (8378, 'Bus Stop', 'The Hollies')
# Searching for "Bus Stop" by The Hollies...
# Done.
# (8379, 'É Bom Parar', 'Francisco Alves')
# Searching for "É Bom Parar" by Francisco Alves...
# Done.
# (8380, 'Tema di Martin (Version 2)', 'Maurice Jarre')
# Searching for "Tema di Martin (Version 2)" by Maurice Jarre...
# Done.
# (8381, "Des ronds dans l'eau - Remasterisé en 2016", 'Françoise Hardy')
# Searching for "Des ronds dans l'eau - Remasterisé en 2016" by Françoise Hardy...
# No results found for: 'Des ronds dans l'eau - Remasterisé en 2016 Françoise Hardy'
# (8382, 'Cançó del Remordiment', 'Raimon')
# Searching for "Cançó del Remordiment" by Raimon...
# Done.
# (8383, 'Dear Hearts And Gentle People', 'The Springfields')
# Searching for "Dear Hearts And Gentle People" by The Springfields...
# Done.
# (8384, 'Dabble In Om', 'Krokodil')
# Searching for "Dabble In Om" by Krokodil...
# Done.
# (8385, 'Serene', 'Eric Dolphy')
# Searching for "Serene" by Eric Dolphy...
# Done.
# (8386, 'Native Quarter', 'Jerry Goldsmith')
# Searching for "Native Quarter" by Jerry Goldsmith...
# Specified song does not contain lyrics. Rejecting.
# (8387, 'Non, Non, Non,...', 'Traditional')
# Searching for "Non, Non, Non,..." by Traditional...
# Done.
# (8388, 'Pauvre doudou', 'Joe Dassin')
# Searching for "Pauvre doudou" by Joe Dassin...
# Done.
# (8389, 'Jingo', 'Santana')
# Searching for "Jingo" by Santana...
# Done.
# (8390, 'Monk Time', 'The Monks')
# Searching for "Monk Time" by The Monks...
# Done.
# (8391, 'Tuesday Afternoon (Forever Afternoon)', 'The Moody Blues')
# Searching for "Tuesday Afternoon (Forever Afternoon)" by The Moody Blues...
# Done.
# (8392, 'Madama Butterfly, Act I: Gran ventura (Butterfly, Coro, Pinkerton, Sharpless, Goro)', 'Giacomo Puccini')
# Searching for "Madama Butterfly, Act I: Gran ventura (Butterfly, Coro, Pinkerton, Sharpless, Goro)" by Giacomo Puccini...
# No results found for: 'Madama Butterfly, Act I: Gran ventura (Butterfly, Coro, Pinkerton, Sharpless, Goro) Giacomo Puccini'
# (8393, "I'm Getting Sentimental Over You", 'Charles Mingus')
# Searching for "I'm Getting Sentimental Over You" by Charles Mingus...
# Specified song does not contain lyrics. Rejecting.
# (8394, 'Early in the Morning', 'Lord Invader')
# Searching for "Early in the Morning" by Lord Invader...
# Done.
# (8395, 'Kavidhayil Ezhudhiya', 'P. Susheela')
# Searching for "Kavidhayil Ezhudhiya" by P. Susheela...
# No results found for: 'Kavidhayil Ezhudhiya P. Susheela'
# (8396, 'Só Danço Samba', 'Sérgio Mendes')
# Searching for "Só Danço Samba" by Sérgio Mendes...
# Done.
# (8397, "These Boots Are Made For Walkin'", 'Nancy Sinatra')
# Searching for "These Boots Are Made For Walkin'" by Nancy Sinatra...
# Done.
# (8398, 'Who Do You Love', 'The Sapphires')
# Searching for "Who Do You Love" by The Sapphires...
# Done.
# (8399, 'The Entertainer', 'Tony Clarke')
# Searching for "The Entertainer" by Tony Clarke...
# Done.
# (8400, 'Diane', 'The Bachelors')
# Searching for "Diane" by The Bachelors...
# Done.
# (8401, 'Do-Wah-Diddy', 'The Exciters')
# Searching for "Do-Wah-Diddy" by The Exciters...
# Done.
# (8402, 'Antigua', 'Antônio Carlos Jobim')
# Searching for "Antigua" by Antônio Carlos Jobim...
# Specified song does not contain lyrics. Rejecting.
# (8403, 'Alla maniera del free jazz', 'Benedetto Ghiglia')
# Searching for "Alla maniera del free jazz" by Benedetto Ghiglia...
# Searching for "Alla maniera del free jazz" by Benedetto Ghiglia...
# Done.
# (8404, 'Downtown', 'Mrs. Miller')
# Searching for "Downtown" by Mrs. Miller...
# Done.
# (8405, 'Oh Buck Buck', 'P. Susheela')
# Searching for "Oh Buck Buck" by P. Susheela...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 11
#       9 while searching:
#      10     try:
# ---> 11         song = genius.search_song(track, artist)
#      12         searching = False
#      13     except Exception:
#
# File ~/Desktop/ACV/.venv/lib/python3.8/site-packages/lyricsgenius/genius.py:436, in Genius.search_song(self, title, artist, song_id, get_full_info)
#     432     song_info.update(new_info)
#     434 if (song_info['lyrics_state'] == 'complete'
#     435         and not song_info.get('instrumental')):
# --> 436     lyrics = self.lyrics(song_url=song_info['url'])
#     437 else:
#     438     lyrics = ""
#
# File ~/Desktop/ACV/.venv/lib/python3.8/site-packages/lyricsgenius/genius.py:132, in Genius.lyrics(self, song_id, song_url, remove_section_headers)
#     128     path = self.song(song_id)['song']['path'][1:]
#     130 # Scrape the song lyrics from the HTML
#     131 html = BeautifulSoup(
# --> 132     self._make_request(path, web=True).replace('<br/>', '\n'),
#     133     "html.parser"
#     134 )
#     136 # Determine the class of the div
#     137 div = html.find("div", class_=re.compile("^lyrics$|Lyrics__Root"))
#
# File ~/Desktop/ACV/.venv/lib/python3.8/site-packages/lyricsgenius/api/base.py:75, in Sender._make_request(self, path, method, params_, public_api, web, **kwargs)
#      73 tries += 1
#      74 try:
# ---> 75     response = self._session.request(method, uri,
#      76                                      timeout=self.timeout,
#      77                                      params=params_,
#      78                                      headers=header,
#      79                                      **kwargs)
#      80     response.raise_for_status()
#      81 except Timeout as e:
#
# File ~/Desktop/ACV/.venv/lib/python3.8/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Desktop/ACV/.venv/lib/python3.8/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Desktop/ACV/.venv/lib/python3.8/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/Desktop/ACV/.venv/lib/python3.8/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~/Desktop/ACV/.venv/lib/python3.8/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Desktop/ACV/.venv/lib/python3.8/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py:1322, in HTTPConnection.getresponse(self)
#    1320 try:
#    1321     try:
# -> 1322         response.begin()
#    1323     except ConnectionError:
#    1324         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py:303, in HTTPResponse.begin(self)
#     301 # read until we get a non-100 response
#     302 while True:
# --> 303     version, status, reason = self._read_status()
#     304     if status != CONTINUE:
#     305         break
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py:264, in HTTPResponse._read_status(self)
#     263 def _read_status(self):
# --> 264     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265     if len(line) > _MAXLINE:
#     266         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:
