# %%
import pandas as pd

# %%
! pwd
# Out:
# /songsnap/songsnap

# %%
reference = pd.read_csv("localDataset.csv")

# %%
reference.columns
# Out:
# Index(['Unnamed: 0', 'track', 'artist', 'uri', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature',
#        'chorus_hit', 'sections', 'target', 'bucket', 'popularity', 'genre'],
#       dtype='object')

# %%
reference.head()
# Out:
#    Unnamed: 0                                      track          artist  \
# 0       22107                              Get Some More       Funk Inc.
# 1       12527                           Batuque de Praia          Fagner
# 2        2790                                  Eternally   Sarah Vaughan
# 3        3109  Não é Papo Pra Mim - Versão remasterizada  Roberto Carlos
# 4        6615                               She Said Yes  Wilson Pickett
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:6ZEOlVA2ei1JGEn2D4TejO         0.798   0.601    0    -9.386
# 1  spotify:track:6tLLOuJ9wVvSuCR84T8QXG         0.688   0.635    2    -7.042
# 2  spotify:track:1xYZbzKH9rRC2x0tiOVgB7         0.238   0.282    5   -12.521
# 3  spotify:track:57cYZKHtxmiNtEm9SZ2l25         0.782   0.521    4   -11.705
# 4  spotify:track:3NuKKai62W3W8etSaNqarg         0.671   0.500    0   -15.499
#
# ...

# %%
audio_data = pd.read_csv("audioScraper/bucketed.csv")

# %%
audio_data
# Out:
#                                                    track           artist  \
# 0      Wednesday Night Prayer Meeting - Alternative Take   Charles Mingus
# 1                          Where The Little Jesus Sleeps  Harry Belafonte
# 2                          Jehovah The Lord Will Provide  Harry Belafonte
# 3                                           Silent Night  Harry Belafonte
# 4                                           The Baby Boy  Harry Belafonte
# ...                                                  ...              ...
# 28889                                      Lotus Flowers            Yolta
# 28890                                  Calling My Spirit      Kodak Black
# 28891                                      Teenage Dream       Katy Perry
# 28892                                     Stormy Weather   Oscar Peterson
# 28893                                               Dust      Hans Zimmer
#
#                                         uri  danceability  energy  key  \
# ...

# %%
audio_data.columns

# missing popularity, genre, also LYRICS
# Out:
# Index(['track', 'artist', 'uri', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature', 'chorus_hit',
#        'sections', 'target', 'bucket'],
#       dtype='object')

# %%
genre_df = pd.read_csv("genre_music.csv")

# %%
genre_df = genre_df[["track", "artist", "genre"]].drop_duplicates(["track","artist"])
genre_df.head()
# Out:
#                    track            artist genre
# 0  Jealous Kind Of Fella     Garland Green   edm
# 1          Initials B.B.  Serge Gainsbourg   pop
# 2           Melody Twist       Lord Melody   pop
# 3          Mi Bomba Sonó        Celia Cruz   pop
# 4            Uravu Solla       P. Susheela   r&b

# %%
lyrics_df = pd.read_csv("lyrics_cleaned.csv").drop_duplicates(["track","artist"])

# %%
lyrics_df.head()
# Out:
#                    track            artist  \
# 0  Jealous Kind Of Fella     Garland Green
# 1          Initials B.B.  Serge Gainsbourg
# 2           Melody Twist       Lord Melody
# 3          Mi Bomba Sonó        Celia Cruz
# 4            Uravu Solla       P. Susheela
#
#                                               lyrics
# 0  3 ContributorsJealous Kind of Fella Lyrics[Int...
# 1  14 ContributorsInitials B.B. Lyrics[Paroles de...
# 2  1 ContributorJuice (haeY haeY) LyricsHook (Kro...
# 3  2 ContributorsMi Bomba Sonó LyricsAcó, mi bomb...
# 4                                                  0

# %%
new_df = audio_data.copy()
new_df
# Out:
#                                                    track           artist  \
# 0      Wednesday Night Prayer Meeting - Alternative Take   Charles Mingus
# 1                          Where The Little Jesus Sleeps  Harry Belafonte
# 2                          Jehovah The Lord Will Provide  Harry Belafonte
# 3                                           Silent Night  Harry Belafonte
# 4                                           The Baby Boy  Harry Belafonte
# ...                                                  ...              ...
# 28889                                      Lotus Flowers            Yolta
# 28890                                  Calling My Spirit      Kodak Black
# 28891                                      Teenage Dream       Katy Perry
# 28892                                     Stormy Weather   Oscar Peterson
# 28893                                               Dust      Hans Zimmer
#
#                                         uri  danceability  energy  key  \
# ...

# %%
new_df = new_df.merge(genre_df, how="left", on=["track", "artist"]).merge(lyrics_df, how="left", on=["track", "artist"])

# %%
new_df
# Out:
#                                                    track           artist  \
# 0      Wednesday Night Prayer Meeting - Alternative Take   Charles Mingus
# 1                          Where The Little Jesus Sleeps  Harry Belafonte
# 2                          Jehovah The Lord Will Provide  Harry Belafonte
# 3                                           Silent Night  Harry Belafonte
# 4                                           The Baby Boy  Harry Belafonte
# ...                                                  ...              ...
# 28889                                      Lotus Flowers            Yolta
# 28890                                  Calling My Spirit      Kodak Black
# 28891                                      Teenage Dream       Katy Perry
# 28892                                     Stormy Weather   Oscar Peterson
# 28893                                               Dust      Hans Zimmer
#
#                                         uri  danceability  energy  key  \
# ...

# %%
new_df.to_csv("complete_dataset.csv")
